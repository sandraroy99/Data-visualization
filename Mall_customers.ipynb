# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\sandr\OneDrive\Desktop\Mall_Customers.csv")
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df["Age"].plot()
# Out:
# <Axes: >

# %%
df.plot(kind ='scatter',x ='Age', y="Annual Income (k$)")
# Out:
# <Axes: xlabel='Age', ylabel='Annual Income (k$)'>

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    112
# Male       88
# Name: count, dtype: int64

# %%
q= round(df.groupby("Gender")["Spending Score (1-100)"].mean(),2)
print(Rank_totals)
Rank_totals.plot(kind ='bar')
# Out:
#         Spending Score (1-100)  Annual Income (k$)
# Gender
# Female               51.526786           59.250000
# Male                 48.511364           62.227273
# <Axes: xlabel='Gender'>

# %%
q= df.groupby(["Gender"])[["Spending Score (1-100)","Annual Income (k$)"]].mean()
print(Rank_totals)
Rank_totals.plot(kind ='bar',alpha=0.6,stacked =True)
# Out:
#         Spending Score (1-100)  Annual Income (k$)
# Gender
# Female               51.526786           59.250000
# Male                 48.511364           62.227273
# <Axes: xlabel='Gender'>

# %%
q= df.groupby(["Gender"])[["Spending Score (1-100)","Annual Income (k$)"]].mean()
print(Rank_totals)
Rank_totals.plot(kind ='bar',alpha=0.6)
# Out:
#         Spending Score (1-100)  Annual Income (k$)
# Gender
# Female               51.526786           59.250000
# Male                 48.511364           62.227273
# <Axes: xlabel='Gender'>

# %%
q.plot(kind ='pie',subplots =True)
# Out:
# array([<Axes: ylabel='Spending Score (1-100)'>,
#        <Axes: ylabel='Annual Income (k$)'>], dtype=object)

# %%
df['Age'].plot(kind ='bar')
df['Age'].plot.bar()
# Out:
# <Axes: >

# %%
q.plot.bar(color =['green','red'],subplots =True,rot =45)
# Out:
# array([<Axes: title={'center': 'Spending Score (1-100)'}, xlabel='Gender'>,
#        <Axes: title={'center': 'Annual Income (k$)'}, xlabel='Gender'>],
#       dtype=object)

# %%
df['Annual Income (k$)'].plot(kind ='box')
# Out:
# <Axes: >

# %%
df[['Age','Annual Income (k$)']].plot.box()
# Out:
# <Axes: >

# %%
import numpy as np
q2=np.quantile(df['Annual Income (k$)'],0.5)
print("q2",q2)
q1 =np.quantile(df['Annual Income (k$)'],0.25)
print("q1",q1)
q3 =np.quantile(df['Annual Income (k$)'],0.75)
print("q3",q3)
iqr = (q3-q1)
print("iqr",iqr)
[q3-1.5*iqr,q1+1.5*iqr]
min,max = q3 -1.5*iqr,q1+1.5*iqr
iqrrange=[min,max]
iqrrange
# Out:
# q2 61.5
# q1 41.5
# q3 78.0
# iqr 36.5
# [23.25, 96.25]

# %%
Ai_in_range=df[(df['Annual Income (k$)'] >=min) & (df['Annual Income (k$)']<= max)] 
Ai_in_range.count()
# Out:
# CustomerID                160
# Gender                    160
# Age                       160
# Annual Income (k$)        160
# Spending Score (1-100)    160
# dtype: int64

# %%
Ai_in_range['Annual Income (k$)'].plot(kind ='box',vert =False)
# Out:
# <Axes: >

# %%
df[['Age','Annual Income (k$)']].plot(kind ='area',alpha =0.3)
# Out:
# <Axes: >

# %%
df[['Age','Annual Income (k$)']].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df.plot(kind ='hexbin', x='Age', y ='Annual Income (k$)')
# Out:
# <Axes: xlabel='Age', ylabel='Annual Income (k$)'>

# %%
df.plot(kind ='hexbin', x='Age', y ='Annual Income (k$)',gridsize =10,figsize =(7,6))
# Out:
# <Axes: xlabel='Age', ylabel='Annual Income (k$)'>

# %%
df.plot(kind ='scatter', x='Age', y ='Annual Income (k$)',figsize =(8,4),
        title='Age and annual income information', ylabel ='Annual income in  dollar',
        xlabel='Age of the candidate',marker ='X',color ='red');

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df, alpha=1,figsize=(10,6));

# %%
pd.plotting.bootstrap_plot(df['Annual Income (k$)'])

# %%
from pandas.plotting import bootstrap_plot
bootstrap_plot(df['Annual Income (k$)'])
